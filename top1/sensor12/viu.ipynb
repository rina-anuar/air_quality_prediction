# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('sensor12.csv')
# Assuming your data is in a CSV or DataFrame 'df'
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)

# %%
df.index = pd.to_datetime(df.index)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure datetime index
df.index = pd.to_datetime(df.index)

plt.figure(figsize=(12, 6))

# Use .dropna() for the specific sensor to ensure the line connects points
sensor_data = df['12'].dropna()
plt.plot(sensor_data.index, sensor_data, marker='o', markersize=4, linestyle='-', color='black', label='Sensor 12')

# Define range
start_date = pd.to_datetime('2019-06-01')
end_date = pd.to_datetime('2019-06-15')

plt.xlim(pd.to_datetime('2019-07-25'), pd.to_datetime('2019-08-05'))

plt.title('AQI Sensor 12 - June 2019 Highlight')
plt.legend()
plt.grid(True, alpha=0.2)
plt.show()
